# %% [markdown]
# <a href="https://colab.research.google.com/github/nhoiyee/Practice-codes/blob/master/food_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O "code_warriors_game_of_data_ai_challenge-dataset.zip" "https://dockship-job-models.s3.ap-south-1.amazonaws.com/9e0846542a8e05988521a399befd189c?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIDOPTEUZ2LEOQEGQ%2F20200921%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20200921T131447Z&X-Amz-Expires=1800&X-Amz-Signature=563464724718e2bb47d8ba8f885bdc7835bc714f137351d6ed58df36c241b133&X-Amz-SignedHeaders=host&response-content-disposition=attachment%3B%20filename%3D%22code_warriors_game_of_data_ai_challenge-dataset.zip%22"
# Out:
# --2020-09-21 13:15:23--  https://dockship-job-models.s3.ap-south-1.amazonaws.com/9e0846542a8e05988521a399befd189c?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIDOPTEUZ2LEOQEGQ%2F20200921%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Date=20200921T131447Z&X-Amz-Expires=1800&X-Amz-Signature=563464724718e2bb47d8ba8f885bdc7835bc714f137351d6ed58df36c241b133&X-Amz-SignedHeaders=host&response-content-disposition=attachment%3B%20filename%3D%22code_warriors_game_of_data_ai_challenge-dataset.zip%22
# Resolving dockship-job-models.s3.ap-south-1.amazonaws.com (dockship-job-models.s3.ap-south-1.amazonaws.com)... 52.219.62.87
# Connecting to dockship-job-models.s3.ap-south-1.amazonaws.com (dockship-job-models.s3.ap-south-1.amazonaws.com)|52.219.62.87|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444775416 (424M) [binary/octet-stream]
# Saving to: ‘code_warriors_game_of_data_ai_challenge-dataset.zip’
#
# ...

# %%
import os
import zipfile


base_dir = '/tmp/code_warriors_game_of_data_ai_challenge-dataset.zip'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# %%
#import required modules
import os
from zipfile import ZipFile
#specifying the zip file name
file_name= "code_warriors_game_of_data_ai_challenge-dataset.zip"
#open the zip file in READ mode
with ZipFile(file_name, 'r') as zip:

  #print all contents of the zip file 
  zip.printdir()

  #extract all the files
  print('Extracting all the files now...')
  zip.extractall()
  print('Done!')
# Out:
# Streaming output truncated to the last 5000 lines.
# test/0125.jpg                                  2020-09-09 15:57:06        38413
# test/0820.jpg                                  2020-09-09 15:57:06        99400
# test/0920.jpg                                  2020-09-09 15:57:06        38396
# test/0010.jpg                                  2020-09-09 15:57:06        39613
# test/0022.jpg                                  2020-09-09 15:57:06        44213
# test/1461.jpg                                  2020-09-09 15:57:06        42135
# test/1434.jpg                                  2020-09-09 15:57:06        50551
# test/0128.jpg                                  2020-09-09 15:57:06        42154
# test/0423.jpg                                  2020-09-09 15:57:06        30838
# test/1204.jpg                                  2020-09-09 15:57:06        27477
# test/0135.jpg                                  2020-09-09 15:57:06        78212
# ...

# %%
# Directory with our training bread pictures
train_bread_dir = os.path.join(train_dir, 'bread')

# Directory with our training dairy_product pictures
train_dairy_product_dir = os.path.join(train_dir, 'dairy_product')

# %%
# Directory with our training dessert pictures
train_dessert_dir = os.path.join(train_dir, 'dessert')

# Directory with our training egg pictures
train_egg_dir = os.path.join(train_dir, 'egg')

# Directory with our training fried food pictures
train_fried_food_dir = os.path.join(train_dir, 'fried food')

# Directory with our training meat pictures
train_meat_dir = os.path.join(train_dir, 'meat')

# Directory with our training Noodles-Pasta pictures
train_noodles_pasta_dir = os.path.join(train_dir, 'noodles-pasta')

# Directory with our training rice pictures
train_rice_dir = os.path.join(train_dir, 'rice')

# Directory with our training seafood pictures
train_seafood_dir = os.path.join(train_dir, 'seafood')

# Directory with our training soup pictures
train_soup_dir = os.path.join(train_dir, 'soup')

# Directory with our training vegetable-fruit pictures
train_vegetable_fruit_dir= os.path.join(train_dir, 'vegetable-fruit')

# %%
# Directory with our validation bread pictures
validation_bread_dir = os.path.join(validation_dir, 'bread')

# Directory with our validation dairy_product pictures
validation_dairy_product_dir = os.path.join(validation_dir, 'dairy_product')
